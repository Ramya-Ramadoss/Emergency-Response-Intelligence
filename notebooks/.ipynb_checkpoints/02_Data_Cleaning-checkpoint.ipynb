# %% [markdown]
# # 🧹 Emergency Response Intelligence
#
# ## Data Cleaning
#
# ### Notebook Objective
#
# This notebook focuses on improving the quality of the emergency response dataset before preprocessing and exploratory data analysis.
#
# The following data cleaning techniques will be performed:
#
# - Missing value handling
# - Duplicate record analysis
# - Data type conversion
# - Text cleaning
# - Whitespace removal
# - Standardization
# - Invalid value detection
# - Outlier identification
# - Data validation

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

pd.set_option("display.max_columns", None)

print("✅ Libraries Imported Successfully")

# %% [markdown]
# # 📂 Create Working Copy
#
# Instead of modifying the original dataset directly, a duplicate copy is created.
#
# This ensures that the raw dataset always remains unchanged.
