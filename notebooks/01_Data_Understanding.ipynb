# %% [markdown]
# # 🚑 Emergency Response Intelligence
#
# ## Data Understanding
#
# ### Project
#
# Emergency Response Intelligence:
# An End-to-End Data Preparation and Exploratory Data Analysis Project
#
# ---
#
# ### Notebook Objective
#
# The purpose of this notebook is to understand the structure, quality, and characteristics of the Montgomery County 911 Emergency Calls dataset before performing any preprocessing or analysis.
#
# This notebook covers:
#
# - Dataset overview
# - Library imports
# - Data loading
# - Dataset dimensions
# - Feature descriptions
# - Data types
# - Missing value analysis
# - Duplicate analysis
# - Initial statistical summary
# - Preliminary observations
#
# Author: Ramya Ramadoss

# %% [markdown]
# # Import Required Libraries

# %%
# ==========================================
# Emergency Response Intelligence
# Notebook 01 - Data Understanding
# ==========================================

# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Missing Value Visualization
import missingno as msno

# Ignore Warnings
import warnings
warnings.filterwarnings("ignore")

# Display Settings
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)

# Plot Style
plt.style.use("ggplot")
sns.set_theme(style="whitegrid")

print("Libraries imported successfully.")

# %% [markdown]
# # Load Dataset
